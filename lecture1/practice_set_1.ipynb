# %% [markdown]
# ### Question 1 :
# What will be the output of the following code?

# %%
x = 5
if x > 3:
    print("Greater than 3")
print("Done")
# Out:
# Greater than 3
# Done

# %% [markdown]
# ### Question 2 :
# You want to store your name, age, and your city in Python variables.
# Write code to declare and print these variables.

# %%
name = "Karan"
age = 21
city = "Ahmedabad"
print(name)
print(age)
print(city)
# Out:
# Karan
# 21
# Ahmedabad

# %% [markdown]
# ### Question 3 :
# Rewrite the following code by adding appropriate comments explaining what each part does:

# %%
num = 10
# 10 is assigned to variable num
square = num * num
# num * num is performed and assigned the final value inside square variable
print(square)
# it prints the square
# Out:
# 100

# %% [markdown]
# ### Question 4 :
# How many statements are in the following line of Python code?
# Explain what each statement does.

# %%
x = 3; y = x + 5; print(y)
# there are 3 statements separated by a ";" 
# x = 3 assigns value 3 in x
# y = x + 5 makes first addition of x and 5 and then the value is assigned to y
# print(y) prints y
# Out:
# 8

# %% [markdown]
# ### Question 5 :
# Is the following code valid in Python? If yes, what does it print?
# If no, explain the mistake.

# %%
a = 10; b = 20; 
print(a+b);
# Out:
# 30
